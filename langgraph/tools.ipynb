# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

api_wrapper = WikipediaAPIWrapper(
    top_k_results = 5,
    doc_content_chars_max = 500
)

wikipedia_tool = WikipediaQueryRun(api_wrapper = api_wrapper)

# wikipedia_tool.name
# wikipedia_tool.description
# wikipedia_tool.args

wikipedia_tool.invoke(   
    {'query': "Elon Musk"}
) ## or wikipedia_tool.run()
# Out:
# "Page: Elon Musk\nSummary: Elon Reeve Musk ( EE-lon; born June 28, 1971) is a businessman known for his leadership of Tesla, SpaceX, X (formerly Twitter) and DOGE. Musk has been considered the wealthiest person in the world since 2021; as of May 2025, Forbes estimates his net worth to be US$424.7 billion. \nBorn to a wealthy family in Pretoria, South Africa, Musk emigrated in 1989 to Canada. He received bachelor's degrees from the University of Pennsylvania in 1997 before moving to California, Unit"

# %%
from langchain_community.tools import YouTubeSearchTool

youtube_tool = YouTubeSearchTool()

# youtube_tool.name
# youtube_tool.description
# youtube_tool.args

youtube_tool.invoke("Elon Musk")
# Out:
# "['https://www.youtube.com/watch?v=OXJVrU2gO3g&pp=ygUJRWxvbiBNdXNr', 'https://www.youtube.com/watch?v=8Q4GlGps2zw&pp=ygUJRWxvbiBNdXNr']"

# %%
import os
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

load_dotenv()
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")

tavily_tool = TavilySearchResults()

# tavily_tool.name
# tavily_tool.description
# tavily_tool.args

tavily_tool.invoke("Oneplus 13s")
# Out:
# [{'title': 'OnePlus 13s - Full phone specifications - GSMArena.com',
#   'url': 'https://www.gsmarena.com/oneplus_13s_5g-13818.php',
#   'content': '|  |  |  |\n| --- | --- | --- |\n| Display | [Type](glossary.php3?term=display-type) | LTPO AMOLED, 1B colors, 120Hz, 2160Hz PWM, Dolby Vision, HDR10+, HDR Vivid, 1600 nits (HBM) |\n| [Size](#) | 6.32 inches, 97.9 cm2 (~90.6% screen-to-body ratio) |\n| [Resolution](glossary.php3?term=resolution) | 1216 x 2640 pixels, 19.5:9 ratio (~460 ppi density) |\n| [Protection](glossary.php3?term=screen-protection) | Crystal Shield Glass | [...] |  |  |  |\n| --- | --- | --- |\n| Main Camera | [Dual](glossary.php3?term=camera) | 50 MP, f/1.8, 24mm (wide), 1/1.56", 1.0µm, multi-directional PDAF, OIS  50 MP, f/2.0, (telephoto), 1/2.75", 0.64µm, 2x optical zoom, PDAF |\n| [Features](glossary.php3?term=camera) | Color spectrum sensor, LED flash, HDR, panorama |\n| [Video](glossary.php3?term=camera) | 4K@30/60fps, 1080p@30/60/240fps, gyro-EIS, OIS, Dolby Vision HDR | [...] |  |  |  |\n| --- | --- | --- |\n| Body | [Dimensions](#) | 150.8 x 71.7 x 8.2 mm (5.94 x 2.82 x 0.32 in) |\n| [Weight](#) | 185 g (6.53 oz) |\n| [Build](glossary.php3?term=build) | Glass front, aluminum alloy frame |\n| [SIM](glossary.php3?term=sim) | Nano-SIM + Nano-SIM |\n|  | IP65 dust tight and water resistant (low pressure water jets) |',
#   'score': 0.8194462},
#  {'title': "One Plus 13S Review: What's the S For? - YouTube",
#   'url': 'https://www.youtube.com/watch?v=eLusurjBcCs',
#   'content': "OnePlus 13S is technically on the smaller end of the flagship spectrum. Too bad it's India and China only.",
#   'score': 0.7539928},
#  {'title': 'OnePlus 13s Coming soon',
#   'url': 'https://www.oneplus.in/launch/13s',
#   'content': "OnePlus 13s will be available in OnePlus official online store soon. Stronger, Smarter, Smaller. Tap 'Notify Me' to get the updates on the OnePlus 13s.",
#   'score': 0.7171114},
#  {'title': "OnePlus 13s Review: What Others Didn't Tell You! - YouTube",
#   'url': 'https://www.youtube.com/watch?v=40OawwG9H7Y',
#   'content': 'Hi everyone, in this video, we have reviewed the OnePlus 13s after 10 days of use. Find out more about its pros, cons, etc in this video!',
#   'score': 0.68748367},
#  {'title': 'The diminutive OnePlus 13s is official with impressive specs and a ...',
#   'url': 'https://www.phonearena.com/news/oneplus-13s-official-specs-features-price-india-release_id171044',
#   'content': '6.32-inch AMOLED display with 2640 x 1216 pixel resolution and 120Hz refresh rate capabilities; · Qualcomm Snapdragon 8 Elite processor; · 256 and',
#   'score': 0.685971}]

# %% [markdown]
# #### Custom tools

# %%
from langchain_core.tools import tool

@tool
def multiply(a: int, b: int)->int:
    '''Multiplication function'''
    return a*b

multiply.invoke({"a": 10, "b": 20})
# Out:
# 200
